# %%
# !beeline -u "jdbc:hive2://thriftserver:10001/default" -e "SELECT h3, country, pollutant, avg_measurement, ST_AsText(geom) FROM  analytics.density_map LIMIT 5;"
# Out:
# Connecting to jdbc:hive2://thriftserver:10001/default
# Connected to: Spark SQL (version 3.5.4)
# Driver: Hive JDBC (version 2.3.9)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# +---------------------+----------+------------+----------------------------+----------------------------------------------------+
# |         h3          | country  | pollutant  |      avg_measurement       |                  st_astext(geom)                   |
# +---------------------+----------+------------+----------------------------+----------------------------------------------------+
# | 599506708221394943  | Austria  | PM10       | 20.1599990000000000000000  | POLYGON ((16.657838750396305 47.860136509493465, 16.659936132718666 47.77400083486406, 16.77821609308585 47.7345697087627, 16.89457768082784 47.78123503750557, 16.89274354657032 47.86739125258208, 16.774284457038586 47.90686176932623, 16.657838750396305 47.860136509493465)) |
# ...
