# %%
from sedona.spark import SedonaContext
import os
import geopandas as gpd
from IPython.display import HTML
from shapely.wkt import loads

# %%
def show_map(m):
    return HTML(f"<div style='width:800px; height:500px'>{m._repr_html_()}</div>")

# %%
# %%capture
bucket_name = os.environ.get("SEDONA_SOURCE_BUCKET", "apache-sedona-book")

config = SedonaContext.builder()

sedona = SedonaContext.create(config.getOrCreate())

sedona.sparkContext.setLogLevel("ERROR")

sc = sedona.sparkContext
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/07 18:11:52 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/12/07 18:11:53 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/12/07 18:11:55 WARN UDTRegistration: Cannot register UDT for org.geotools.coverage.grid.GridCoverage2D, which is already registered.
# 25/12/07 18:11:55 WARN SimpleFunctionRegistry: The function rs_union_aggr replaced a previously registered function.
# 25/12/07 18:11:55 WARN UDTRegistration: Cannot register UDT for org.locationtech.jts.geom.Geometry, which is already registered.
# 25/12/07 18:11:55 WARN UDTRegistration: Cannot register UDT for org.apache.sedona.common.S2Geography.Geography, which is already registered.
# 25/12/07 18:11:55 WARN UDTRegistration: Cannot register UDT for org.locationtech.jts.index.SpatialIndex, which is already registered.
# 25/12/07 18:11:55 WARN SimpleFunctionRegistry: The function st_envelope_aggr replaced a previously registered function.
# 25/12/07 18:11:55 WARN SimpleFunctionRegistry: The function st_envelope_aggr replaced a previously registered function.
# 25/12/07 18:11:55 WARN SimpleFunctionRegistry: The function st_intersection_aggr replaced a previously registered function.
# 25/12/07 18:11:55 WARN SimpleFunctionRegistry: The function st_intersection_aggr replaced a previously registered function.
# 25/12/07 18:11:55 WARN SimpleFunctionRegistry: The function st_union_aggr replaced a previously registered function.
# 25/12/07 18:11:55 WARN SimpleFunctionRegistry: The function st_union_aggr replaced a previously registered function.

# %% [markdown]
# # Geometry constructors

# %%
sedona.sql(
    """
    SELECT ST_GeomFromText('POINT (151.241012 -33.843705)') AS geom
    """
).show()
# Out:
# +--------------------+
# |                geom|
# +--------------------+
# |POINT (151.241012...|
# +--------------------+

# %%
sedona.sql(
    """
    SELECT ST_GeomFromText('POINT (151.241012 -33.843705)') AS geom
        
    """
).createOrReplaceTempView("points")

# %% [markdown]
# # Geometry functions

# %%
sedona.sql(
    """
    SELECT 
        ST_GeometryType(geom) AS geom_type
    FROM points
        
    """
).show()
# Out:
# +---------+
# |geom_type|
# +---------+
# | ST_Point|
# +---------+

# %%
sedona.sql(
    """
    SELECT 
        ST_SRID(geom) AS srid
    FROM points
    """
).show()
# Out:
# +----+
# |srid|
# +----+
# |   0|
# +----+

# %%
sedona.sql(
    """
    SELECT 
        ST_Transform(ST_SetSRID(geom, 4326), 'EPSG:3857') AS geom
    FROM points
    """
).show(1, False)
# Out:
# +---------------------------------------------+
# |geom                                         |
# +---------------------------------------------+
# |POINT (16836072.44289938 -4007834.6839636774)|
# +---------------------------------------------+

# %%
sedona.sql(
    """
    SELECT 
        ST_SRID(ST_Transform(ST_SetSRID(geom, 4326), 'EPSG:3857')) AS geom
    FROM points
    """
).show(1, False)
# Out:
# +----+
# |geom|
# +----+
# |3857|
# +----+

# %% [markdown]
# # Distance functions

# %%
# point inside polygon, distance 0

# %%
sedona.sql(
    """
    SELECT ST_Distance(
        ST_GeomFromText('Point(0 0)'),
        ST_GeomFromText('Polygon((-1 -1, -1 2, 2 2, 2 -1, -1 -1))')
    ) AS dist
    """
).show()
# Out:
# +----+
# |dist|
# +----+
# | 0.0|
# +----+

# %%
# normal distance

# %%
sedona.sql(
    """
    SELECT ST_Distance(
        ST_GeomFromText('Point(-2 -2)'),
        ST_GeomFromText('Polygon((-1 -1, -1 2, 2 2, 2 -1, -1 -1))')
    ) AS dist
    """
).show()
# Out:
# +------------------+
# |              dist|
# +------------------+
# |1.4142135623730951|
# +------------------+

# %%
sedona.sql(
    """
    SELECT ST_Distance(
        ST_GeomFromText('Point(-2 -2)'),
        ST_GeomFromText('Polygon((2 2, 2 -1, -1 -1, -1 2, 2 2))')
    ) AS dist
    """
).show()
# Out:
# +------------------+
# |              dist|
# +------------------+
# |1.4142135623730951|
# +------------------+

# %%
# distance between closest points

# %%
sedona.sql(
    """
    SELECT ST_Distance(
        ST_GeomFromText('Point(-2 -2)'),
        ST_GeomFromText('Point(-1 -1)')
    ) AS dist
    """
).show()
# Out:
# +------------------+
# |              dist|
# +------------------+
# |1.4142135623730951|
# +------------------+

# %%
sedona.sql(
    """
    SELECT ST_Distance(
        ST_GeomFromText('Point(-2 -2)'),
        ST_GeomFromText('Point(2 2)')
    ) AS dist
    """
).show()
# Out:
# +-----------------+
# |             dist|
# +-----------------+
# |5.656854249492381|
# +-----------------+

# %%
## distance to centroid

# %%
sedona.sql(
    """
    SELECT ST_Distance(
        ST_GeomFromText('Point(-2 -2)'),
        ST_Centroid(ST_GeomFromText('Polygon((-1 -1, -1 2, 2 2, 2 -1, -1 -1))'))
    ) AS dist
    """
).show()
# Out:
# +------------------+
# |              dist|
# +------------------+
# |3.5355339059327378|
# +------------------+

# %%
# share common points geometries

# %%
geom_left = "Polygon((-1 -1, 2 3, 2 2, 2 -1, -1 -1))"
geom_right = "Polygon((-1 -1, -1 2, 2 2, 2 -1, -1 -1))"

# %%
loads(f'GEOMETRYCOLLECTION({geom_left}, {geom_right})')
# Out:
# <GEOMETRYCOLLECTION (POLYGON ((-1 -1, 2 3, 2 2, 2 -1, -1 -1)), POLYGON ((-1 ...>

# %%
sedona.sql(
    f"""
    SELECT ST_Distance(
        ST_GeomFromText('{geom_left}'),
        ST_GeomFromText('{geom_right}')
    ) AS dist
    """
).show()
# Out:
# +----+
# |dist|
# +----+
# | 0.0|
# +----+

# %%
geom_left = "Polygon((2 2, 2 3, 3 3, 3 2, 2 2))"
geom_right = "Polygon((-1 -1, -1 2, 2 2, 2 -1, -1 -1))"
loads(f'GEOMETRYCOLLECTION({geom_left}, {geom_right})')
# Out:
# <GEOMETRYCOLLECTION (POLYGON ((2 2, 2 3, 3 3, 3 2, 2 2)), POLYGON ((-1 -1, -...>

# %%
sedona.sql(
    f"""
    SELECT ST_Distance(
        ST_GeomFromText('{geom_left}'),
        ST_GeomFromText('{geom_right}')
    ) AS dist
    """
).show()
# Out:
# +----+
# |dist|
# +----+
# | 0.0|
# +----+

# %%
geom_left = "Polygon((1.9 1.9, 1.9 3, 3 3, 3 1.9, 1.9 1.9))"
geom_right = "Polygon((-1 -1, -1 2, 2 2, 2 -1, -1 -1))"
loads(f'GEOMETRYCOLLECTION({geom_left}, {geom_right})')
# Out:
# <GEOMETRYCOLLECTION (POLYGON ((1.9 1.9, 1.9 3, 3 3, 3 1.9, 1.9 1.9)), POLYGO...>

# %%
sedona.sql(
    f"""
    SELECT ST_Distance(
        ST_GeomFromText('{geom_left}'),
        ST_GeomFromText('{geom_right}')
    ) AS dist
    """
).show()
# Out:
# +----+
# |dist|
# +----+
# | 0.0|
# +----+

# %% [markdown]
# # Transforming Vietnam road Data

# %%
roads = sedona.\
    read.\
    format("shapefile").\
    load(f"s3a://{bucket_name}/source_data/vietnam_roads/gis_osm_roads_free_1.shp")

roads.createOrReplaceTempView("roads")
roads.cache().count()
# Out:
# 3022375

# %% [markdown]
# # ST_Simplify function

# %%
show_map(gpd.GeoDataFrame(roads.where("osm_id=211733913").selectExpr("ST_Simplify(geometry, 0.01) AS geometry").toPandas(), geometry="geometry").explore(   zoom_start=11,))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 show_map(gpd.GeoDataFrame(roads.where("osm_id=211733913").selectExpr("ST_Simplify(geometry, 0.01) AS geometry").toPandas(), geometry="geometry").explore(   zoom_start=11,))
#
# NameError: name 'show_map' is not defined

# %%
show_map(gpd.GeoDataFrame(roads.where("osm_id=211733913").selectExpr("geometry").toPandas(), geometry="geometry").explore(   zoom_start=11,))

# %%
roads.select("osm_id", "name", "fclass", "geometry").show(5)
# Out:
# +-------+----------------+-----------+--------------------+
# | osm_id|            name|     fclass|            geometry|
# +-------+----------------+-----------+--------------------+
# |9566542|     Cầu Thê Húc|    footway|LINESTRING (105.8...|
# |9656653|      Phố Mã Mây|residential|LINESTRING (105.8...|
# |9656730|Cầu Chương Dương|    primary|LINESTRING (105.8...|
# |9963509|    Phố Hàng Cót|   tertiary|LINESTRING (105.8...|
# |9964440|Phố Quốc Tử Giám|residential|LINESTRING (105.8...|
# +-------+----------------+-----------+--------------------+
# only showing top 5 rows

# %% [markdown]
# # Preparing data for routing dataset, using the ST_StartPoint and ST_EndPoint function

# %%
sedona.sql(
"""
    SELECT 
        osm_id as id,
        ST_StartPoint(geometry) AS geom
    FROM roads
    UNION ALL
    SELECT 
        osm_id as id,
        ST_EndPoint(geometry) AS geom
    FROM roads
"""    
).show()
# Out:
# +--------+--------------------+
# |      id|                geom|
# +--------+--------------------+
# | 9566542|POINT (105.852999...|
# | 9656653|POINT (105.853446...|
# | 9656730|POINT (105.865640...|
# | 9963509|POINT (105.847163...|
# | 9964440|POINT (105.838099...|
# | 9964551|POINT (105.82426 ...|
# | 9964663|POINT (105.842177...|
# | 9965723|POINT (105.853230...|
# | 9975059|POINT (105.888769...|
# | 9978719|POINT (105.893973...|
# |10045075|POINT (105.801391...|
# |10046571|POINT (105.798351...|
# |10047796|POINT (105.778322...|
# |10047852|POINT (105.841426...|
# |10047949|POINT (105.845505...|
# |10048048|POINT (105.843671...|
# |10048345|POINT (105.778322...|
# |10049443|POINT (105.810260...|
# |10049446|POINT (105.818639...|
# |10230410|POINT (105.855307...|
# +--------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Finding roads to block before marathon using the ST_ConvexHull function

# %%
sedona.sql(
    """
    SELECT 
        ST_ConvexHull(ST_Union_Aggr(geometry))
    FROM roads 
    WHERE (name = 'Phố Giảng Võ' or name = 'Phố Kim Mã') and fclass = 'primary'
    """
    
).collect()[0][0]
# Out:
# <POLYGON ((105.82 21.023, 105.82 21.023, 105.82 21.024, 105.82 21.024, 105.8...>

# %%
sedona.sql(
    """
    SELECT ST_ConvexHull(ST_Union_Aggr(geometry)) AS geom
    FROM roads 
    where (name = 'Phố Giảng Võ' or name = 'Phố Kim Mã') and fclass = 'primary'
    """
    
).createOrReplaceTempView("convex_hull")

# %%
sedona.sql(
    """
    SELECT DISTINCT name
    FROM roads
    WHERE ST_Intersects(geometry, (
        SELECT
            ST_Transform(
                ST_Buffer(
                    ST_Transform(geom, 'EPSG:3405'),
                    500
                ),
                'EPSG:4326'
            ) as geom
        FROM convex_hull
    ))
    """
).show(5)
# Out:
# [Stage 32:>                                                         (0 + 1) / 1]
# +--------------------+
# |                name|
# +--------------------+
# |     Ngõ 152 Hào Nam|
# |      Ngõ Quan Thổ 1|
# |   Ngõ 20 Thành Công|
# | Ngõ 8B Phố Vũ Thạnh|
# |Ngõ 156 Mai Anh Tuấn|
# +--------------------+
# only showing top 5 rows

# %%
sedona.sql(
    """
    SELECT DISTINCT name
    FROM roads
    WHERE ST_DWithin(geometry, (SELECT geom FROM convex_hull), 500, true)
    """
).show()
# Out:
# [Stage 38:>                                                         (0 + 1) / 1]
# +--------------------+
# |                name|
# +--------------------+
# | Ngõ 8B Phố Vũ Thạnh|
# |Ngách 6 Ngõ 189 G...|
# |    Ngõ 20A Núi Trúc|
# |Ngách 1 Ngõ 2 Vũ ...|
# |    Ngõ 149 Giảng Võ|
# |     Ngõ 127 Hào Nam|
# |     Ngõ 29 Vũ Thạnh|
# |    Ngõ 187 Giảng Võ|
# |      Ngõ 39 Hào Nam|
# |Ngách 99 Ngõ 318 ...|
# |Ngách 48 Ngõ 29 V...|
# | Ngõ 466 Đê La Thành|
# |         Phố Nam Cao|
# |Ngõ 418 Đường La ...|
# |     Ngõ 167 Hào Nam|
# |     Ngõ 95 Giảng Võ|
# |Ngách 360/4 La Thành|
# |        Phố Vũ Thạnh|
# |Ngách 23 Ngõ 127 ...|
# |Hẻm 1 Ngách 1 Ngõ...|
# +--------------------+
# only showing top 20 rows
